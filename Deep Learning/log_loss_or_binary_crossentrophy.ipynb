# %%
import numpy as np

# %%
import math

# %%
y_predicted=np.array([1,1,0,0,1])
y_true=np.array([0.30,0.7,1,0,0.5])

# %% [markdown]
# mean absolute error

# %%
def mean_absolute_error(y_true,y_predicted):
    total_error=0
    for yt,yp in zip(y_true,y_predicted):
        total_error += abs(yp-yt)
        # abs will give us absolute difference 

    print("total error ",total_error)
    mae=total_error/len(y_true)
    print("mean_absolute_error",mae)

# %%
mean_absolute_error(y_true,y_predicted)
# Out:
# total error  2.5
# mean_absolute_error 0.5

# %%
y_predicted-y_true
# Out:
# array([ 0.7,  0.3, -1. ,  0. ,  0.5])

# %%
np.abs(y_predicted-y_true)
# Out:
# array([0.7, 0.3, 1. , 0. , 0.5])

# %%
np.sum(np.abs(y_predicted-y_true))
# Out:
# 2.5

# %%
np.mean(np.abs(y_predicted-y_true))
# Out:
# 0.5

# %% [markdown]
# mean squared error

# %%
def mean_squared_error(y_true,y_predicted):
    total_error=0
    for tv,pv in zip(y_true,y_predicted):
        total_error += pow(abs(tv-pv),2)
    print("total error ",total_error)
    msq=total_error/len(y_true)
    print(msq)

# %%
mean_squared_error(y_true,y_predicted)
# Out:
# total error  1.83
# 0.366

# %% [markdown]
# knowing important thing about log

# %%
np.log(0)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_7228\2933082444.py:1: RuntimeWarning: divide by zero encountered in log
#   np.log(0)
# -inf

# %%
np.log([0.000000000000001])
# Out:
# array([-34.53877639])

# %% [markdown]
# so we come to know that log zero is infinte so it is not defiend on that

# %% [markdown]
# log loss or binary cross entrophy =1/n(Eyi log(y predicted)+(1-yi).log(1-ypredicted))

# %% [markdown]
# we cannot take y predicted and true as 1 because it will let you go to the log 0 whic is termed to infintie

# %%
eplison=1e-15

# %%
eplison
# Out:
# 1e-15

# %%
y_predicted
# Out:
# array([1, 1, 0, 0, 1])

# %%
y_predicted_new =[max(i,eplison) for i in y_predicted]

# %%
y_predicted_new
# Out:
# [1, 1, 1e-15, 1e-15, 1]

# %%
y_predicted_new=(min(i,1-eplison) for i in y_predicted_new)

# %%
y_predicted_new
# Out:
# <generator object <genexpr> at 0x000002130C6E2F20>

# %%
for i in y_predicted_new:
    print(i)
# Out:
# 0.999999999999999
# 0.999999999999999
# 1e-15
# 1e-15
# 0.999999999999999

# %%
-np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'generator' object has no attribute 'log'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\hp\Desktop\data sciene\Deep Learning\log_loss_or_binary_crossentrophy.ipynb Cell 28 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/data%20sciene/Deep%20Learning/log_loss_or_binary_crossentrophy.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
#
# TypeError: loop of ufunc does not support argument 0 of type generator which has no callable log method
